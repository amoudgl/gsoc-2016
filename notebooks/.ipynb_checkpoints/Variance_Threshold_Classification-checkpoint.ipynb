// %% [markdown]
// <img src="http://oproject.org/tiki-download_file.php?fileId=8&display&x=450&y=128" height="200" width="200"  />
// <img class="middle-img" src="http://gfif.udea.edu.co/root/tmva/img/tmva_logo.gif" height="200" width="200" />
// # Variance Threshold Transformation
// <hr style="border-top-width: 6px; border-top-color: #34609b">
// This notebook demonstrates the Variable Transformation method in DataLoader class by code samples and visual plots.

// %% [markdown]
// ## Introduction
//
// In high energy physics and machine learning problems, we often encounter data which have large number of input variables. However to extract maximum information from the data, we need to select the relevant input variables for the multivariate classification and regression methods implemented in TMVA. Variance Threshold is a simple unsupervised variable selection method which automates this process.
//
// It computes weighted variance $\sigma^2_V$ for each variable $V$ and ignores the ones whose variance doesn't meet a specific threshold. Weighted variance for each variable is defined as follows:
// $$\sigma^2_V = \frac{\sum_{i=1}^N w_i (x_i - \mu_V)^2}{\sum_{i=1}^N w_i}$$
//
// where $N$ is the number of events in a dataset, $x_i$ denotes the value of variable for the $i$th event, $w_i$ is the weight of each event and $\mu_V$ denotes the weighted mean of variable.
// $$\mu_V = \frac{\sum_{i=1}^N w_i x_i}{\sum_{i=1}^N w_i}$$
//
// A threshold $T$ for variance can be set by user otherwise default value of threshold is zero i.e. remove the variables which have same value in all the events. We get a new set of variables $S$ which can be formally defined as:
//
// $$S = \{V  \mid \sigma^2_V > T \}$$

// %% [markdown]
// ## Initialize DataLoader and Factory

// %%
TMVA::Tools::Instance();
TFile *inputFile = TFile::Open( "../datasets/mydataset.root"); 
TFile* outputFile = TFile::Open( "mydataset_output.root", "RECREATE" );
TMVA::Factory *factory = new TMVA::Factory("TMVAClassification", outputFile, 
                                           "!V:ROC:!Correlations:!Silent:Color:!DrawProgressBar:AnalysisType=Classification" );
TMVA::DataLoader *loader1=new TMVA::DataLoader("mydataset");
// Out:
// --- Factory                  : You are running ROOT Version: 6.07/07, Apr 1, 2016
// --- Factory                  :
// --- Factory                  : _/_/_/_/_/ _|      _|  _|      _|    _|_|
// --- Factory                  :    _/      _|_|  _|_|  _|      _|  _|    _|
// --- Factory                  :   _/       _|  _|  _|  _|      _|  _|_|_|_|
// --- Factory                  :  _/        _|      _|    _|  _|    _|    _|
// --- Factory                  : _/         _|      _|      _|      _|    _|
// --- Factory                  :
// --- Factory                  : ___________TMVA Version 4.2.1, Feb 5, 2015
// --- Factory                  :

// %% [markdown]
// ## Setup DataLoader

// %%
loader1->AddVariable("var0", 'F');
loader1->AddVariable("var1", 'F');
loader1->AddVariable("var2", 'F');
loader1->AddVariable("var3 := var0-var1", 'F');
loader1->AddVariable("var4 := var0*var2", 'F');
loader1->AddVariable("var5 := var1+var2", 'F');
TTree *tsignal = (TTree*)inputFile->Get("MyMCSig");
TTree *tbackground = (TTree*)inputFile->Get("MyMCBkg");
TCut mycuts = "";
TCut mycutb = "";
loader1->AddSignalTree( tsignal,     1.0 );
loader1->AddBackgroundTree( tbackground, 1.0 );
loader1->PrepareTrainingAndTestTree( mycuts, mycutb,"nTrain_Signal=3000:nTrain_Background=3000:nTest_Signal=1449:nTest_Background=1449:SplitMode=Random:NormMode=NumEvents:!V");
// Out:
// --- DataSetInfo              : Dataset[mydataset] : Added class "Signal"	 with internal class number 0
// --- Configurable             : Add Tree MyMCSig of type Signal with 5449 events
// --- DataSetInfo              : Dataset[mydataset] : Added class "Background"	 with internal class number 1
// --- Configurable             : Add Tree MyMCBkg of type Background with 5449 events
// --- Configurable             : Preparing trees for training and testing...

// %% [markdown]
// ## Apply Variance Threshold
//
// After having dataset loaded in DataLoader with all the variables, we are now ready to apply Variance Threshold transformation. It is implemented in VarTransform method in [DataLoader](https://root.cern.ch/doc/master/classTMVA_1_1DataLoader.html) class.
//
// ### Method Definition
// Parameters: Transformation definition string
// Returns: DataLoader with selected subset of variables
//
// Transformation defintion string **should only follow** either of the following formats otherwise method would raise an error.
//
// |String            | Description                                                            |
// |------------------|------------------------------------------------------------------------|
// |"VT"              | Select variables whose variance is above threshold value = 0 (Default) |
// |"VT(float_value)" | Select variables whose variance lies above float_value passed.         |

// %%
TMVA::DataLoader* loader2 = loader1->VarTransform("VT(2.95)");
// Out:
// --- DataSetFactory           : Dataset[mydataset] : Splitmode is: "RANDOM" the mixmode is: "SAMEASSPLITMODE"
// --- DataSetFactory           : Dataset[mydataset] : Create training and testing trees -- looping over class "Signal" ...
// --- DataSetFactory           : Dataset[mydataset] : Weight expression for class 'Signal': ""
// --- DataSetFactory           : Dataset[mydataset] : Create training and testing trees -- looping over class "Background" ...
// --- DataSetFactory           : Dataset[mydataset] : Weight expression for class 'Background': ""
// --- DataSetFactory           : Dataset[mydataset] : Number of events in input trees (after possible flattening of arrays):
// --- DataSetFactory           : Dataset[mydataset] :     Signal      -- number of events       : 5449  / sum of weights: 5449
// --- DataSetFactory           : Dataset[mydataset] :     Background      -- number of events       : 5449  / sum of weights: 5449
// --- DataSetFactory           : Dataset[mydataset] :     Signal tree -- total number of entries: 5449
// --- DataSetFactory           : Dataset[mydataset] :     Background tree -- total number of entries: 5449
// --- DataSetFactory           : Dataset[mydataset] : Preselection: (will NOT affect number of requested training and testing events)
// --- DataSetFactory           : Dataset[mydataset] :     No preselection cuts applied on event classes
// --- DataSetFactory           : Dataset[mydataset] : Weight renormalisation mode: "NumEvents": renormalises all event classes
// --- DataSetFactory           : Dataset[mydataset] :  such that the effective (weighted) number of events in each class equals the respective
// --- DataSetFactory           : Dataset[mydataset] :  number of events (entries) that you demanded in PrepareTrainingAndTestTree("","nTrain_Signal=.. )
// --- DataSetFactory           : Dataset[mydataset] :  ... i.e. such that Sum[i=1..N_j]{w_i} = N_j, j=0,1,2...
// --- DataSetFactory           : Dataset[mydataset] :  ... (note that N_j is the sum of TRAINING events (nTrain_j...with j=Signal,Background..
// --- DataSetFactory           : Dataset[mydataset] :  ..... Testing events are not renormalised nor included in the renormalisation factor! )
// --- DataSetFactory           : Dataset[mydataset] : --> Rescale Signal event weights by factor: 1
// --- DataSetFactory           : Dataset[mydataset] : --> Rescale Background event weights by factor: 1
// --- DataSetFactory           : Dataset[mydataset] : Number of training and testing events after rescaling:
// --- DataSetFactory           : Dataset[mydataset] : ---------------------------------------------------------------------------
// --- DataSetFactory           : Dataset[mydataset] : Signal -- training events            : 3000 (sum of weights: 3000) - requested were 3000 events
// --- DataSetFactory           : Dataset[mydataset] : Signal -- testing events             : 1449 (sum of weights: 1449) - requested were 1449 events
// --- DataSetFactory           : Dataset[mydataset] : Signal -- training and testing events: 4449 (sum of weights: 4449)
// --- DataSetFactory           : Dataset[mydataset] : Background -- training events            : 3000 (sum of weights: 3000) - requested were 3000 events
// --- DataSetFactory           : Dataset[mydataset] : Background -- testing events             : 1449 (sum of weights: 1449) - requested were 1449 events
// --- DataSetFactory           : Dataset[mydataset] : Background -- training and testing events: 4449 (sum of weights: 4449)
// --- DataSetFactory           : Dataset[mydataset] : Create internal training tree
// --- DataSetFactory           : Dataset[mydataset] : Create internal testing tree
// --- DataSetInfo              : Dataset[mydataset] : Correlation matrix (Signal):
// --- DataSetInfo              : ----------------------------------------------------------------
// --- DataSetInfo              :  var0var1var2var0-var1var0*var2var1+var2
// --- DataSetInfo              : var0:+1.000-0.008+0.011+0.852+0.922+0.000
// --- DataSetInfo              : var1:-0.008+1.000+0.010-0.531-0.004+0.811
// --- DataSetInfo              : var2:+0.011+0.010+1.000+0.004+0.335+0.593
// --- DataSetInfo              : var0-var1:+0.852-0.531+0.004+1.000+0.784-0.425
// --- DataSetInfo              : var0*var2:+0.922-0.004+0.335+0.784+1.000+0.192
// --- DataSetInfo              : var1+var2:+0.000+0.811+0.593-0.425+0.192+1.000
// --- DataSetInfo              : ----------------------------------------------------------------
// --- DataSetInfo              : Dataset[mydataset] : Correlation matrix (Background):
// --- DataSetInfo              : ----------------------------------------------------------------
// --- DataSetInfo              :  var0var1var2var0-var1var0*var2var1+var2
// --- DataSetInfo              : var0:+1.000-0.008+0.008+0.650+0.670-0.001
// --- DataSetInfo              : var1:-0.008+1.000+0.009-0.766+0.001+0.738
// --- DataSetInfo              : var2:+0.008+0.009+1.000-0.002+0.696+0.682
// --- DataSetInfo              : var0-var1:+0.650-0.766-0.002+1.000+0.431-0.561
// --- DataSetInfo              : var0*var2:+0.670+0.001+0.696+0.431+1.000+0.471
// --- DataSetInfo              : var1+var2:-0.001+0.738+0.682-0.561+0.471+1.000
// --- DataSetInfo              : ----------------------------------------------------------------
// --- DataSetFactory           : Dataset[mydataset] :
// --- VarTransformHandler      : Number of events - 6000
// --- VarTransformHandler      : ----------------------------------------------------------------
// --- VarTransformHandler      : VariablesVariance
// --- VarTransformHandler      : ----------------------------------------------------------------
// --- VarTransformHandler      : var02.83513
// --- VarTransformHandler      : var12.02377
// --- VarTransformHandler      : var21.45872
// --- VarTransformHandler      : var0-var14.95813
// --- VarTransformHandler      : var0*var257.202
// --- VarTransformHandler      : var1+var23.14537
// --- VarTransformHandler      : ----------------------------------------------------------------
// --- VarTransformHandler      : TargetsVariance
// --- VarTransformHandler      : ----------------------------------------------------------------
// --- VarTransformHandler      : Set minNorm/maxNorm for variables to:
// --- VarTransformHandler      :     var0	: [0.0433797	, 9.99504	]
// --- VarTransformHandler      :     var1	: [9.9424e-05	, 4.99673	]
// --- VarTransformHandler      :     var2	: [0.000886448	, 4.99926	]
// --- VarTransformHandler      :     var0-var1	: [-4.44537	, 9.96153	]
// --- VarTransformHandler      :     var0*var2	: [0.000883656	, 48.22	]
// --- VarTransformHandler      :     var1+var2	: [0.14162	, 9.87022	]
// --- VarTransformHandler      : Set minNorm/maxNorm for targets to:
// --- VarTransformHandler      : Number of variables before transformation: 6
// --- VarTransformHandler      : Selecting variables whose variance is above threshold value = 2.95
// --- VarTransformHandler      : ----------------------------------------------------------------
// --- VarTransformHandler      : Selected VariablesVariance
// --- VarTransformHandler      : ----------------------------------------------------------------
// --- VarTransformHandler      : var0-var14.95813
// --- VarTransformHandler      : var0*var257.202
// --- VarTransformHandler      : var1+var23.14537
// --- VarTransformHandler      : ----------------------------------------------------------------
// --- Configurable             : Preparing trees for training and testing...
// --- DataSetInfo              : Dataset[default] : Added class "Signal"	 with internal class number 0
// --- DataSetInfo              : Dataset[default] : Added class "Background"	 with internal class number 1
// --- VarTransformHandler      : Number of variables after transformation: 3

// %%
//Boosted Decision Trees
factory->BookMethod(loader1,TMVA::Types::kBDT, "BDT",
                   "!V:NTrees=200:MinNodeSize=2.5%:MaxDepth=2:BoostType=AdaBoost:AdaBoostBeta=0.5:UseBaggedBoost:BaggedSampleFraction=0.5:SeparationType=GiniIndex:nCuts=20" );

//Multi-Layer Perceptron (Neural Network)
factory->BookMethod(loader1, TMVA::Types::kMLP, "MLP",
                   "!H:!V:NeuronType=tanh:VarTransform=N:NCycles=100:HiddenLayers=N+5:TestRate=5:!UseRegulator" );

factory->BookMethod(loader1, TMVA::Types::kFisher, "Fisher",
"H:!V:Fisher:CreateMVAPdfs:PDFInterpolMVAPdf=Spline2:NbinsMVAPdf=60:\
NsmoothMVAPdf=10" );

//Cut optimisation using Monte Carlo sampling
// factory->BookMethod(loader1, TMVA::Types::kCuts, "Cuts",
// "!H:!V:FitMethod=MC:EffSel:SampleSize=200000:VarProp=FSmart" );

//Support Vector Machine
factory->BookMethod(loader1, TMVA::Types::kSVM, "SVM", "Gamma=0.25:Tol=0.001" );

// DNN 
TString layoutString ("Layout=TANH|100,TANH|50,TANH|10,LINEAR");
TString training0 ("LearningRate=1e-1,Momentum=0.0,Repetitions=1,ConvergenceSteps=300,BatchSize=20,TestRepetitions=15,WeightDecay=0.001,Regularization=NONE,DropConfig=0.0+0.5+0.5+0.5,DropRepetitions=1,Multithreading=True");
TString training1 ("LearningRate=1e-2,Momentum=0.5,Repetitions=1,ConvergenceSteps=300,BatchSize=30,TestRepetitions=7,WeightDecay=0.001,Regularization=L2,Multithreading=True,DropConfig=0.0+0.1+0.1+0.1,DropRepetitions=1");
TString trainingStrategyString ("TrainingStrategy=");
trainingStrategyString += training0 + "|" + training1;
TString nnOptions ("!H:V:ErrorStrategy=CROSSENTROPY:VarTransform=G:WeightInitialization=XAVIERUNIFORM");
nnOptions.Append (":");
nnOptions.Append (layoutString);
nnOptions.Append (":");
nnOptions.Append (trainingStrategyString);
factory->BookMethod(loader1, TMVA::Types::kDNN, "DNN", nnOptions );
// Out:
// --- Factory                  : Booking method: BDT DataSet Name: mydataset
// --- Factory                  : Booking method: MLP DataSet Name: mydataset
// --- MLP                      : Dataset[mydataset] : Create Transformation "N" with events from all classes.
// --- Norm                     : Transformation, Variable selection :
// --- Norm                     : Input : variable 'var0' (index=0).   <---> Output : variable 'var0' (index=0).
// --- Norm                     : Input : variable 'var1' (index=1).   <---> Output : variable 'var1' (index=1).
// --- Norm                     : Input : variable 'var2' (index=2).   <---> Output : variable 'var2' (index=2).
// --- Norm                     : Input : variable 'var3' (index=3).   <---> Output : variable 'var3' (index=3).
// --- Norm                     : Input : variable 'var4' (index=4).   <---> Output : variable 'var4' (index=4).
// --- Norm                     : Input : variable 'var5' (index=5).   <---> Output : variable 'var5' (index=5).
// --- MLP                      : Building Network
// --- MLP                      : Initializing weights
// --- Factory                  : Booking method: Fisher DataSet Name: mydataset
// --- Factory                  : Booking method: Cuts DataSet Name: mydataset
// --- Cuts                     : Use optimization method: "Monte Carlo"
// --- Cuts                     : Use efficiency computation method: "Event Selection"
// --- Cuts                     : Use "FSmart" cuts for variable: 'var0'
// --- Cuts                     : Use "FSmart" cuts for variable: 'var1'
// --- Cuts                     : Use "FSmart" cuts for variable: 'var2'
// --- Cuts                     : Use "FSmart" cuts for variable: 'var3'
// --- Cuts                     : Use "FSmart" cuts for variable: 'var4'
// --- Cuts                     : Use "FSmart" cuts for variable: 'var5'
// --- Factory                  : Booking method: SVM DataSet Name: mydataset

// %%
//Boosted Decision Trees
factory->BookMethod(loader2,TMVA::Types::kBDT, "BDT",
                   "!V:NTrees=200:MinNodeSize=2.5%:MaxDepth=2:BoostType=AdaBoost:AdaBoostBeta=0.5:UseBaggedBoost:BaggedSampleFraction=0.5:SeparationType=GiniIndex:nCuts=20" );

//Multi-Layer Perceptron (Neural Network)
factory->BookMethod(loader2, TMVA::Types::kMLP, "MLP",
                   "!H:!V:NeuronType=tanh:VarTransform=N:NCycles=100:HiddenLayers=N+5:TestRate=5:!UseRegulator" );

factory->BookMethod(loader2, TMVA::Types::kFisher, "Fisher",
"H:!V:Fisher:CreateMVAPdfs:PDFInterpolMVAPdf=Spline2:NbinsMVAPdf=60:\
NsmoothMVAPdf=10" );

//Support Vector Machine
factory->BookMethod(loader2, TMVA::Types::kSVM, "SVM", "Gamma=0.25:Tol=0.001" );

//DNN
factory->BookMethod(loader2, TMVA::Types::kDNN, "DNN", nnOptions );
// Out:
// --- Factory                  : Booking method: BDT DataSet Name: transformed_dataset
// --- DataSetFactory           : Dataset[default] : Splitmode is: "RANDOM" the mixmode is: "SAMEASSPLITMODE"
// --- DataSetFactory           : Dataset[default] : Create training and testing trees -- looping over class "Signal" ...
// --- DataSetFactory           : Dataset[default] : Weight expression for class 'Signal': ""
// --- DataSetFactory           : Dataset[default] : Create training and testing trees -- looping over class "Background" ...
// --- DataSetFactory           : Dataset[default] : Weight expression for class 'Background': ""
// --- DataSetFactory           : Dataset[default] : Number of events in input trees (after possible flattening of arrays):
// --- DataSetFactory           : Dataset[default] :     Signal      -- number of events       : 5449  / sum of weights: 5449
// --- DataSetFactory           : Dataset[default] :     Background      -- number of events       : 5449  / sum of weights: 5449
// --- DataSetFactory           : Dataset[default] :     Signal tree -- total number of entries: 5449
// --- DataSetFactory           : Dataset[default] :     Background tree -- total number of entries: 5449
// --- DataSetFactory           : Dataset[default] : Preselection: (will NOT affect number of requested training and testing events)
// --- DataSetFactory           : Dataset[default] :     No preselection cuts applied on event classes
// --- DataSetFactory           : Dataset[default] : Weight renormalisation mode: "NumEvents": renormalises all event classes
// --- DataSetFactory           : Dataset[default] :  such that the effective (weighted) number of events in each class equals the respective
// --- DataSetFactory           : Dataset[default] :  number of events (entries) that you demanded in PrepareTrainingAndTestTree("","nTrain_Signal=.. )
// --- DataSetFactory           : Dataset[default] :  ... i.e. such that Sum[i=1..N_j]{w_i} = N_j, j=0,1,2...
// --- DataSetFactory           : Dataset[default] :  ... (note that N_j is the sum of TRAINING events (nTrain_j...with j=Signal,Background..
// --- DataSetFactory           : Dataset[default] :  ..... Testing events are not renormalised nor included in the renormalisation factor! )
// --- DataSetFactory           : Dataset[default] : --> Rescale Signal event weights by factor: 1
// --- DataSetFactory           : Dataset[default] : --> Rescale Background event weights by factor: 1
// --- DataSetFactory           : Dataset[default] : Number of training and testing events after rescaling:
// --- DataSetFactory           : Dataset[default] : ---------------------------------------------------------------------------
// --- DataSetFactory           : Dataset[default] : Signal -- training events            : 3000 (sum of weights: 3000) - requested were 3000 events
// --- DataSetFactory           : Dataset[default] : Signal -- testing events             : 1449 (sum of weights: 1449) - requested were 1449 events
// --- DataSetFactory           : Dataset[default] : Signal -- training and testing events: 4449 (sum of weights: 4449)
// --- DataSetFactory           : Dataset[default] : Background -- training events            : 3000 (sum of weights: 3000) - requested were 3000 events
// --- DataSetFactory           : Dataset[default] : Background -- testing events             : 1449 (sum of weights: 1449) - requested were 1449 events
// --- DataSetFactory           : Dataset[default] : Background -- training and testing events: 4449 (sum of weights: 4449)
// --- DataSetFactory           : Dataset[default] : Create internal training tree
// --- DataSetFactory           : Dataset[default] : Create internal testing tree
// --- DataSetInfo              : Dataset[default] : Correlation matrix (Signal):
// --- DataSetInfo              : ----------------------------------------
// --- DataSetInfo              :  var0-var1var0*var2var1+var2
// --- DataSetInfo              : var0-var1:+1.000+0.784-0.425
// --- DataSetInfo              : var0*var2:+0.784+1.000+0.192
// --- DataSetInfo              : var1+var2:-0.425+0.192+1.000
// --- DataSetInfo              : ----------------------------------------
// --- DataSetInfo              : Dataset[default] : Correlation matrix (Background):
// --- DataSetInfo              : ----------------------------------------
// --- DataSetInfo              :  var0-var1var0*var2var1+var2
// --- DataSetInfo              : var0-var1:+1.000+0.431-0.561
// --- DataSetInfo              : var0*var2:+0.431+1.000+0.471
// --- DataSetInfo              : var1+var2:-0.561+0.471+1.000
// --- DataSetInfo              : ----------------------------------------
// --- DataSetFactory           : Dataset[default] :
// --- Factory                  : Booking method: MLP DataSet Name: transformed_dataset
// --- MLP                      : Dataset[default] : Create Transformation "N" with events from all classes.
// --- Norm                     : Transformation, Variable selection :
// --- Norm                     : Input : variable 'var0-var1' (index=0).   <---> Output : variable 'var0-var1' (index=0).
// --- Norm                     : Input : variable 'var0*var2' (index=1).   <---> Output : variable 'var0*var2' (index=1).
// --- Norm                     : Input : variable 'var1+var2' (index=2).   <---> Output : variable 'var1+var2' (index=2).
// --- MLP                      : Building Network
// --- MLP                      : Initializing weights
// --- Factory                  : Booking method: Fisher DataSet Name: transformed_dataset
// --- Factory                  : Booking method: Cuts DataSet Name: transformed_dataset
// --- Cuts                     : Use optimization method: "Monte Carlo"
// --- Cuts                     : Use efficiency computation method: "Event Selection"
// --- Cuts                     : Use "FSmart" cuts for variable: 'var0-var1'
// --- Cuts                     : Use "FSmart" cuts for variable: 'var0*var2'
// --- Cuts                     : Use "FSmart" cuts for variable: 'var1+var2'
// --- Factory                  : Booking method: SVM DataSet Name: transformed_dataset

// %%
factory->TrainAllMethods();
// Out:
// --- Factory                  :
// --- Factory                  : Train all methods for Classification ...
// --- Factory                  :
// --- Factory                  : current transformation string: 'I'
// --- Factory                  : Dataset[mydataset] : Create Transformation "I" with events from all classes.
// --- Id                       : Transformation, Variable selection :
// --- Id                       : Input : variable 'var0' (index=0).   <---> Output : variable 'var0' (index=0).
// --- Id                       : Input : variable 'var1' (index=1).   <---> Output : variable 'var1' (index=1).
// --- Id                       : Input : variable 'var2' (index=2).   <---> Output : variable 'var2' (index=2).
// --- Id                       : Input : variable 'var3' (index=3).   <---> Output : variable 'var3' (index=3).
// --- Id                       : Input : variable 'var4' (index=4).   <---> Output : variable 'var4' (index=4).
// --- Id                       : Input : variable 'var5' (index=5).   <---> Output : variable 'var5' (index=5).
// --- Factory_Id_TF            : Preparing the Identity transformation...
// --- TFHandler_Factory        : -----------------------------------------------------------
// --- TFHandler_Factory        : Variable  Mean RMS   [        Min       Max ]
// --- TFHandler_Factory        : -----------------------------------------------------------
// --- TFHandler_Factory        : var0:     3.0588     1.6838   [   0.043380     9.9950 ]
// --- TFHandler_Factory        : var1:     1.5648     1.4226   [ 9.9424e-05     4.9967 ]
// --- TFHandler_Factory        : var2:     3.5262     1.2078   [ 0.00088645     4.9993 ]
// --- TFHandler_Factory        : var3:     1.4940     2.2267   [    -4.4454     9.9615 ]
// --- TFHandler_Factory        : var4:     10.832     7.5632   [ 0.00088366     48.220 ]
// --- TFHandler_Factory        : var5:     5.0910     1.7735   [    0.14162     9.8702 ]
// --- TFHandler_Factory        : -----------------------------------------------------------
// --- TFHandler_Factory        : Plot event variables for Id
// --- TFHandler_Factory        : Create scatter and profile plots in target-file directory:
// --- TFHandler_Factory        : mydataset_output.root:/mydataset/InputVariables_Id/CorrelationPlots
// --- TFHandler_Factory        :
// --- TFHandler_Factory        : Ranking input variables (method unspecific)...
// --- IdTransformation         : Ranking result (top variable is best ranked)
// --- IdTransformation         : -------------------------
// --- IdTransformation         : Rank : Variable  : Separation
// --- IdTransformation         : -------------------------
// --- IdTransformation         :    1 :  : 2.738e-01
// --- IdTransformation         :    2 :  : 1.314e-01
// --- IdTransformation         :    3 :  : 1.190e-01
// --- IdTransformation         :    4 :  : 9.708e-02
// --- IdTransformation         :    5 :  : 5.815e-02
// --- IdTransformation         :    6 :  : 5.589e-02
// --- IdTransformation         : -------------------------
// --- Factory                  : Train method: BDT for Classification
// --- BDT                      : Dataset[mydataset] : Begin training
// --- BDT                      :  found and suggest the following possible pre-selection cuts
// --- BDT                      : as option DoPreselection was not used, these cuts however will not be performed, but the training will see the full sample
// --- BDT                      :  found cut: Bkg if var 3 < -1.09749
// --- BDT                      : <InitEventSample> For classification trees,
// --- BDT                      :  the effective number of backgrounds is scaled to match
// --- BDT                      :  the signal. Othersise the first boosting step would do 'just that'!
// --- BDT                      : re-normlise events such that Sig and Bkg have respective sum of weights = 1
// --- BDT                      :   sig->sig*1ev. bkg->bkg*1ev.
// --- BDT                      : #events: (reweighted) sig: 3000 bkg: 3000
// --- BDT                      : #events: (unweighted) sig: 3000 bkg: 3000
// --- BDT                      : Training 200 Decision Trees ... patience please
// --- BinaryTree               : The minimal node size MinNodeSize=2.5 fMinNodeSize=2.5% is translated to an actual number of events = 76.175 for the training sample size of 3047
// --- BinaryTree               : Note: This number will be taken as absolute minimum in the node,
// --- BinaryTree               :       in terms of 'weighted events' and unweighted ones !!
// --- BDT                      : <Train> elapsed time: 0.408 sec
// --- BDT                      : <Train> average number of nodes (w/o pruning) : 4
// --- BDT                      : Dataset[mydataset] : End of training
// --- BDT                      : Dataset[mydataset] : Elapsed time for training with 6000 events: 0.432 sec
// --- BDT                      : Dataset[mydataset] : Create MVA output for Dataset[mydataset] : classification on training sample
// --- BDT                      : Dataset[mydataset] : Evaluation of BDT on training sample (6000 events)
// --- BDT                      : Dataset[mydataset] : Elapsed time for evaluation of 6000 events: 0.0982 sec
// --- BDT                      : Dataset[mydataset] : Creating weight file in xml format: mydataset/weights/TMVAClassification_BDT.weights.xml
// --- BDT                      : Dataset[mydataset] : Creating standalone response class: mydataset/weights/TMVAClassification_BDT.class.C
// --- BDT                      : mydataset_output.root:/mydataset/Method_BDT/BDT
// --- Factory                  : Training finished
// --- Factory                  : Train method: MLP for Classification
// --- MLP_Norm_TF              : Preparing the transformation.
// --- TFHandler_MLP            : -----------------------------------------------------------
// --- TFHandler_MLP            : Variable  Mean RMS   [        Min       Max ]
// --- TFHandler_MLP            : -----------------------------------------------------------
// --- TFHandler_MLP            : var0:   -0.39399    0.33839   [    -1.0000     1.0000 ]
// --- TFHandler_MLP            : var1:   -0.37371    0.56942   [    -1.0000     1.0000 ]
// --- TFHandler_MLP            : var2:    0.41058    0.48327   [    -1.0000     1.0000 ]
// --- TFHandler_MLP            : var3:   -0.17548    0.30911   [    -1.0000     1.0000 ]
// --- TFHandler_MLP            : var4:   -0.55077    0.31370   [    -1.0000     1.0000 ]
// --- TFHandler_MLP            : var5:   0.017481    0.36460   [    -1.0000     1.0000 ]
// --- TFHandler_MLP            : -----------------------------------------------------------
// --- MLP                      : Dataset[mydataset] : Begin training
// --- MLP                      : Training Network
// --- MLP                      : Dataset[mydataset] : End of training
// --- MLP                      : Dataset[mydataset] : Elapsed time for training with 6000 events: 4.03 sec
// --- MLP                      : Dataset[mydataset] : Create MVA output for Dataset[mydataset] : classification on training sample
// --- MLP                      : Dataset[mydataset] : Evaluation of MLP on training sample (6000 events)
// --- MLP                      : Dataset[mydataset] : Elapsed time for evaluation of 6000 events: 0.0133 sec
// --- MLP                      : Dataset[mydataset] : Creating weight file in xml format: mydataset/weights/TMVAClassification_MLP.weights.xml
// --- MLP                      : Dataset[mydataset] : Creating standalone response class: mydataset/weights/TMVAClassification_MLP.class.C
// --- MLP                      : Write special histos to file: mydataset_output.root:/mydataset/Method_MLP/MLP
// --- Factory                  : Training finished
// --- Factory                  : Train method: Fisher for Classification
// --- Fisher                   :
// --- Fisher                   : ================================================================
// --- Fisher                   : H e l p   f o r   M V A   m e t h o d   [ Fisher ] :
// --- Fisher                   :
// --- Fisher                   : --- Short description:
// --- Fisher                   :
// --- Fisher                   : Fisher discriminants select events by distinguishing the mean
// --- Fisher                   : values of the signal and background distributions in a trans-
// --- Fisher                   : formed variable space where linear correlations are removed.
// --- Fisher                   :
// --- Fisher                   :    (More precisely: the "linear discriminator" determines
// --- Fisher                   :     an axis in the (correlated) hyperspace of the input
// --- Fisher                   :     variables such that, when projecting the output classes
// --- Fisher                   :     (signal and background) upon this axis, they are pushed
// --- Fisher                   :     as far as possible away from each other, while events
// --- Fisher                   :     of a same class are confined in a close vicinity. The
// --- Fisher                   :     linearity property of this classifier is reflected in the
// --- Fisher                   :     metric with which "far apart" and "close vicinity" are
// --- Fisher                   :     determined: the covariance matrix of the discriminating
// --- Fisher                   :     variable space.)
// --- Fisher                   :
// --- Fisher                   : --- Performance optimisation:
// --- Fisher                   :
// --- Fisher                   : Optimal performance for Fisher discriminants is obtained for
// --- Fisher                   : linearly correlated Gaussian-distributed variables. Any deviation
// --- Fisher                   : from this ideal reduces the achievable separation power. In
// --- Fisher                   : particular, no discrimination at all is achieved for a variable
// --- Fisher                   : that has the same sample mean for signal and background, even if
// --- Fisher                   : the shapes of the distributions are very different. Thus, Fisher
// --- Fisher                   : discriminants often benefit from suitable transformations of the
// --- Fisher                   : input variables. For example, if a variable x in [-1,1] has a
// --- Fisher                   : a parabolic signal distributions, and a uniform background
// --- Fisher                   : distributions, their mean value is zero in both cases, leading
// --- Fisher                   : to no separation. The simple transformation x -> |x| renders this
// --- Fisher                   : variable powerful for the use in a Fisher discriminant.
// --- Fisher                   :
// --- Fisher                   : --- Performance tuning via configuration options:
// --- Fisher                   :
// --- Fisher                   : <None>
// --- Fisher                   :
// --- Fisher                   : <Suppress this message by specifying "!H" in the booking option>
// --- Fisher                   : ================================================================
// --- Fisher                   :
// --- Fisher                   : Dataset[mydataset] : Begin training
// --- <WARNING> Fisher                   : <GetFisherCoeff> matrix is almost singular with deterninant=1.30105e-25 did you use the variables that are linear combinations or highly correlated?
// --- Fisher                   : Results for Fisher coefficients:
// --- Fisher                   : -----------------------
// --- Fisher                   : Variable:Coefficient:
// --- Fisher                   : -----------------------
// --- Fisher                   : var0:-27677.685
// --- Fisher                   : var1:+34690.819
// --- Fisher                   : var2:+7013.412
// --- Fisher                   : var3:+27677.681
// --- Fisher                   : var4:+0.001
// --- Fisher                   : var5:-7013.259
// --- Fisher                   : (offset):-0.347
// --- Fisher                   : -----------------------
// --- Fisher                   : Dataset[mydataset] : End of training
// --- Fisher                   : Dataset[mydataset] : Elapsed time for training with 6000 events: 0.00764 sec
// --- Fisher                   : Dataset[mydataset] : Create MVA output for Dataset[mydataset] : classification on training sample
// --- Fisher                   : Dataset[mydataset] : Evaluation of Fisher on training sample (6000 events)
// --- Fisher                   : Dataset[mydataset] : Elapsed time for evaluation of 6000 events: 0.000973 sec
// --- Fisher_PDFSig            : Validation result for PDF "Fisher_tr_S":
// --- Fisher_PDFSig            :     chi2/ndof(!=0) = 88.0/53 = 1.66 (Prob = 0.00)
// --- Fisher_PDFSig            :     #bins-found(#expected-bins) deviating > [1,2,3,6] sigmas: [12(16),5(2),1(0),1(0)]
// --- Fisher_PDFBkg            : Validation result for PDF "Fisher_tr_B":
// --- Fisher_PDFBkg            :     chi2/ndof(!=0) = 45.6/60 = 0.76 (Prob = 0.92)
// --- Fisher_PDFBkg            :     #bins-found(#expected-bins) deviating > [1,2,3,6] sigmas: [20(19),0(2),0(0),0(0)]
// --- <WARNING> Fisher                   : Dataset[mydataset] : Dataset[mydataset] : could not calculate the separation, distributions fSplS or fSplB are not yet filled
// --- Fisher                   : <CreateMVAPdfs> Separation from histogram (PDF): 0.207 (0.000)
// --- Fisher                   : Dataset[mydataset] : Evaluation of Fisher on training sample
// --- Fisher                   : Dataset[mydataset] : Elapsed time for evaluation of 6000 events: 0.0161 sec
// --- Fisher                   : Dataset[mydataset] : Creating weight file in xml format: mydataset/weights/TMVAClassification_Fisher.weights.xml
// --- Fisher                   : Dataset[mydataset] : Creating standalone response class: mydataset/weights/TMVAClassification_Fisher.class.C
// --- Factory                  : Training finished
// --- Factory                  : Train method: Cuts for Classification
// --- Cuts                     : Dataset[mydataset] : Begin training
// --- FitterBase               : <MCFitter> Sampling, please be patient ...
// --- FitterBase               : Elapsed time: 4.88 sec
// --- Cuts                     : ----------------------------------------
// --- Cuts                     : Cut values for requested signal efficiency: 0.1
// --- Cuts                     : Corresponding background efficiency       : 0.000333333
// --- Cuts                     : Transformation applied to input variables : None
// --- Cuts                     : ----------------------------------------
// --- Cuts                     : Cut[0]: 3.03736 < var0 <= 1e+30
// --- Cuts                     : Cut[1]: -1e+30 < var1 <= 0.363448
// --- Cuts                     : Cut[2]: 1.62636 < var2 <= 1e+30
// --- Cuts                     : Cut[3]: 5.4497 < var3 <= 1e+30
// --- Cuts                     : Cut[4]: 16.5811 < var4 <= 1e+30
// --- Cuts                     : Cut[5]: -1e+30 < var5 <= 5.35374
// --- Cuts                     : ----------------------------------------
// --- Cuts                     : ----------------------------------------
// --- Cuts                     : Cut values for requested signal efficiency: 0.2
// --- Cuts                     : Corresponding background efficiency       : 0.033
// --- Cuts                     : Transformation applied to input variables : None
// --- Cuts                     : ----------------------------------------
// --- Cuts                     : Cut[0]: 3.08788 < var0 <= 1e+30
// --- Cuts                     : Cut[1]: -1e+30 < var1 <= 0.341314
// --- Cuts                     : Cut[2]: 0.569361 < var2 <= 1e+30
// --- Cuts                     : Cut[3]: -1.23671 < var3 <= 1e+30
// --- Cuts                     : Cut[4]: 11.3096 < var4 <= 1e+30
// --- Cuts                     : Cut[5]: -1e+30 < var5 <= 7.00596
// --- Cuts                     : ----------------------------------------
// --- Cuts                     : ----------------------------------------
// --- Cuts                     : Cut values for requested signal efficiency: 0.3
// --- Cuts                     : Corresponding background efficiency       : 0.0723333
// --- Cuts                     : Transformation applied to input variables : None
// --- Cuts                     : ----------------------------------------
// --- Cuts                     : Cut[0]: 0.461481 < var0 <= 1e+30
// --- Cuts                     : Cut[1]: -1e+30 < var1 <= 0.243957
// --- Cuts                     : Cut[2]: 2.14633 < var2 <= 1e+30
// --- Cuts                     : Cut[3]: -1.42093 < var3 <= 1e+30
// --- Cuts                     : Cut[4]: 1.44885 < var4 <= 1e+30
// --- Cuts                     : Cut[5]: -1e+30 < var5 <= 8.73995
// --- Cuts                     : ----------------------------------------
// --- Cuts                     : ----------------------------------------
// --- Cuts                     : Cut values for requested signal efficiency: 0.4
// --- Cuts                     : Corresponding background efficiency       : 0.125
// --- Cuts                     : Transformation applied to input variables : None
// --- Cuts                     : ----------------------------------------
// --- Cuts                     : Cut[0]: 0.202751 < var0 <= 1e+30
// --- Cuts                     : Cut[1]: -1e+30 < var1 <= 1.08371
// --- Cuts                     : Cut[2]: 3.84408 < var2 <= 1e+30
// --- Cuts                     : Cut[3]: -4.32036 < var3 <= 1e+30
// --- Cuts                     : Cut[4]: 1.08852 < var4 <= 1e+30
// --- Cuts                     : Cut[5]: -1e+30 < var5 <= 9.39991
// --- Cuts                     : ----------------------------------------
// --- Cuts                     : ----------------------------------------
// --- Cuts                     : Cut values for requested signal efficiency: 0.5
// --- Cuts                     : Corresponding background efficiency       : 0.221
// --- Cuts                     : Transformation applied to input variables : None
// --- Cuts                     : ----------------------------------------
// --- Cuts                     : Cut[0]: 0.0764946 < var0 <= 1e+30
// --- Cuts                     : Cut[1]: -1e+30 < var1 <= 0.999857
// --- Cuts                     : Cut[2]: 2.02957 < var2 <= 1e+30
// --- Cuts                     : Cut[3]: -2.53063 < var3 <= 1e+30
// --- Cuts                     : Cut[4]: 2.82053 < var4 <= 1e+30
// --- Cuts                     : Cut[5]: -1e+30 < var5 <= 5.3529
// --- Cuts                     : ----------------------------------------
// --- Cuts                     : ----------------------------------------
// --- Cuts                     : Cut values for requested signal efficiency: 0.6
// --- Cuts                     : Corresponding background efficiency       : 0.259667
// --- Cuts                     : Transformation applied to input variables : None
// --- Cuts                     : ----------------------------------------
// --- Cuts                     : Cut[0]: 0.622759 < var0 <= 1e+30
// --- Cuts                     : Cut[1]: -1e+30 < var1 <= 1.49582
// --- Cuts                     : Cut[2]: 2.79377 < var2 <= 1e+30
// --- Cuts                     : Cut[3]: -0.492792 < var3 <= 1e+30
// --- Cuts                     : Cut[4]: 0.0199769 < var4 <= 1e+30
// --- Cuts                     : Cut[5]: -1e+30 < var5 <= 7.50695
// --- Cuts                     : ----------------------------------------
// --- Cuts                     : ----------------------------------------
// --- Cuts                     : Cut values for requested signal efficiency: 0.7
// --- Cuts                     : Corresponding background efficiency       : 0.362333
// --- Cuts                     : Transformation applied to input variables : None
// --- Cuts                     : ----------------------------------------
// --- Cuts                     : Cut[0]: -0.0278224 < var0 <= 1e+30
// --- Cuts                     : Cut[1]: -1e+30 < var1 <= 3.21767
// --- Cuts                     : Cut[2]: 3.20271 < var2 <= 1e+30
// --- Cuts                     : Cut[3]: -0.457304 < var3 <= 1e+30
// --- Cuts                     : Cut[4]: 2.39544 < var4 <= 1e+30
// --- Cuts                     : Cut[5]: -1e+30 < var5 <= 8.15984
// --- Cuts                     : ----------------------------------------
// --- Cuts                     : ----------------------------------------
// --- Cuts                     : Cut values for requested signal efficiency: 0.8
// --- Cuts                     : Corresponding background efficiency       : 0.518667
// --- Cuts                     : Transformation applied to input variables : None
// --- Cuts                     : ----------------------------------------
// --- Cuts                     : Cut[0]: 0.0500314 < var0 <= 1e+30
// --- Cuts                     : Cut[1]: -1e+30 < var1 <= 4.79094
// --- Cuts                     : Cut[2]: 2.91753 < var2 <= 1e+30
// --- Cuts                     : Cut[3]: -2.0658 < var3 <= 1e+30
// --- Cuts                     : Cut[4]: 1.99283 < var4 <= 1e+30
// --- Cuts                     : Cut[5]: -1e+30 < var5 <= 8.49261
// --- Cuts                     : ----------------------------------------
// --- Cuts                     : ----------------------------------------
// --- Cuts                     : Cut values for requested signal efficiency: 0.9
// --- Cuts                     : Corresponding background efficiency       : 0.68
// --- Cuts                     : Transformation applied to input variables : None
// --- Cuts                     : ----------------------------------------
// --- Cuts                     : Cut[0]: 0.176859 < var0 <= 1e+30
// --- Cuts                     : Cut[1]: -1e+30 < var1 <= 4.0392
// --- Cuts                     : Cut[2]: 0.752576 < var2 <= 1e+30
// --- Cuts                     : Cut[3]: -0.403865 < var3 <= 1e+30
// --- Cuts                     : Cut[4]: 2.10744 < var4 <= 1e+30
// --- Cuts                     : Cut[5]: -1e+30 < var5 <= 9.1571
// --- Cuts                     : ----------------------------------------
// --- Cuts                     : Dataset[mydataset] : End of training
// --- Cuts                     : Dataset[mydataset] : Elapsed time for training with 6000 events: 4.89 sec
// --- Cuts                     : Dataset[mydataset] : Create MVA output for Dataset[mydataset] : classification on training sample
// --- Cuts                     : Dataset[mydataset] : Evaluation of Cuts on training sample (6000 events)
// --- Cuts                     : Dataset[mydataset] : Elapsed time for evaluation of 6000 events: 0.000205 sec
// --- Cuts                     : Dataset[mydataset] : Creating weight file in xml format: mydataset/weights/TMVAClassification_Cuts.weights.xml
// --- Cuts                     : Dataset[mydataset] : Creating standalone response class: mydataset/weights/TMVAClassification_Cuts.class.C
// --- Cuts                     : mydataset_output.root:/mydataset/Method_Cuts/Cuts
// --- Factory                  : Training finished
// --- Factory                  : Train method: SVM for Classification
// --- SVM                      : Dataset[mydataset] : Begin training
// --- SVM                      : Building SVM Working Set...with 6000 event instances
// --- SVM                      : Elapsed time for Working Set build: 0.729 sec
// --- SVM                      : Sorry, no computing time forecast available for SVM, please wait ...
// --- SVM                      : Elapsed time: 27.1 sec
// --- SVM                      : Dataset[mydataset] : End of training
// --- SVM                      : Dataset[mydataset] : Elapsed time for training with 6000 events: 27.8 sec
// --- SVM                      : Dataset[mydataset] : Create MVA output for Dataset[mydataset] : classification on training sample
// --- SVM                      : Dataset[mydataset] : Evaluation of SVM on training sample (6000 events)
// --- SVM                      : Dataset[mydataset] : Elapsed time for evaluation of 6000 events: 0.755 sec
// --- SVM                      : Dataset[mydataset] : Creating weight file in xml format: mydataset/weights/TMVAClassification_SVM.weights.xml
// --- SVM                      : Dataset[mydataset] : Creating standalone response class: mydataset/weights/TMVAClassification_SVM.class.C
// --- Factory                  : Training finished
// --- Factory                  :
// --- Factory                  : Ranking input variables (method specific)...
// --- BDT                      : Ranking result (top variable is best ranked)
// --- BDT                      : --------------------------------------
// --- BDT                      : Rank : Variable  : Variable Importance
// --- BDT                      : --------------------------------------
// --- BDT                      :    1 : var3 : 3.392e-01
// --- BDT                      :    2 : var1 : 1.765e-01
// --- BDT                      :    3 : var2 : 1.520e-01
// --- BDT                      :    4 : var5 : 1.230e-01
// --- BDT                      :    5 : var0 : 1.182e-01
// --- BDT                      :    6 : var4 : 9.105e-02
// --- BDT                      : --------------------------------------
// --- MLP                      : Ranking result (top variable is best ranked)
// --- MLP                      : -----------------------------
// --- MLP                      : Rank : Variable  : Importance
// --- MLP                      : -----------------------------
// --- MLP                      :    1 : var0 : 1.836e+01
// --- MLP                      :    2 : var1 : 1.355e+01
// --- MLP                      :    3 : var4 : 5.912e+00
// --- MLP                      :    4 : var3 : 3.838e+00
// --- MLP                      :    5 : var2 : 2.783e+00
// --- MLP                      :    6 : var5 : 1.844e+00
// --- MLP                      : -----------------------------
// --- Fisher                   : Ranking result (top variable is best ranked)
// --- Fisher                   : -------------------------------
// --- Fisher                   : Rank : Variable  : Discr. power
// --- Fisher                   : -------------------------------
// --- Fisher                   :    1 : var2 : 6.040e-02
// --- Fisher                   :    2 : var1 : 5.257e-02
// --- Fisher                   :    3 : var3 : 2.809e-02
// --- Fisher                   :    4 : var4 : 2.010e-02
// --- Fisher                   :    5 : var0 : 8.865e-04
// --- Fisher                   :    6 : var5 : 2.802e-04
// --- Fisher                   : -------------------------------
// --- Factory                  : No variable ranking supplied by classifier: Cuts
// --- Factory                  : No variable ranking supplied by classifier: SVM
// --- Factory                  :
// --- Factory                  : === Destroy and recreate all methods via weight files for testing ===
// --- Factory                  :
// --- MethodBase               : Dataset[mydataset] : Reading weight file: mydataset/weights/TMVAClassification_BDT.weights.xml
// --- BDT                      : Dataset[mydataset] : Read method "BDT" of type "BDT"
// --- BDT                      : Dataset[mydataset] : MVA method was trained with TMVA Version: 4.2.1
// --- BDT                      : Dataset[mydataset] : MVA method was trained with ROOT Version: 6.07/07
// --- MethodBase               : Dataset[mydataset] : Reading weight file: mydataset/weights/TMVAClassification_MLP.weights.xml
// --- MLP                      : Dataset[mydataset] : Read method "MLP" of type "MLP"
// --- MLP                      : Dataset[mydataset] : MVA method was trained with TMVA Version: 4.2.1
// --- MLP                      : Dataset[mydataset] : MVA method was trained with ROOT Version: 6.07/07
// --- MLP                      : Building Network
// --- MLP                      : Initializing weights
// --- MethodBase               : Dataset[mydataset] : Reading weight file: mydataset/weights/TMVAClassification_Fisher.weights.xml
// --- Fisher                   : Dataset[mydataset] : Read method "Fisher" of type "Fisher"
// --- Fisher                   : Dataset[mydataset] : MVA method was trained with TMVA Version: 4.2.1
// --- Fisher                   : Dataset[mydataset] : MVA method was trained with ROOT Version: 6.07/07
// --- MethodBase               : Dataset[mydataset] : Reading weight file: mydataset/weights/TMVAClassification_Cuts.weights.xml
// --- Cuts                     : Dataset[mydataset] : Read method "Cuts" of type "Cuts"
// --- Cuts                     : Dataset[mydataset] : MVA method was trained with TMVA Version: 4.2.1
// --- Cuts                     : Dataset[mydataset] : MVA method was trained with ROOT Version: 6.07/07
// --- Cuts                     : Read cuts optimised using sample of MC events
// --- Cuts                     : Reading 100 signal efficiency bins for 6 variables
// --- MethodBase               : Dataset[mydataset] : Reading weight file: mydataset/weights/TMVAClassification_SVM.weights.xml
// --- SVM                      : Dataset[mydataset] : Read method "SVM" of type "SVM"
// --- SVM                      : Dataset[mydataset] : MVA method was trained with TMVA Version: 4.2.1
// --- SVM                      : Dataset[mydataset] : MVA method was trained with ROOT Version: 6.07/07
// --- Factory                  :
// --- Factory                  : current transformation string: 'I'
// --- Factory                  : Dataset[default] : Create Transformation "I" with events from all classes.
// --- Id                       : Transformation, Variable selection :
// --- Id                       : Input : variable 'var0-var1' (index=0).   <---> Output : variable 'var0-var1' (index=0).
// --- Id                       : Input : variable 'var0*var2' (index=1).   <---> Output : variable 'var0*var2' (index=1).
// --- Id                       : Input : variable 'var1+var2' (index=2).   <---> Output : variable 'var1+var2' (index=2).
// --- Factory_Id_TF            : Preparing the Identity transformation...
// --- TFHandler_Factory        : ----------------------------------------------------------------
// --- TFHandler_Factory        : Variable  Mean RMS   [        Min       Max ]
// --- TFHandler_Factory        : ----------------------------------------------------------------
// --- TFHandler_Factory        : var0-var1:     1.4940     2.2267   [    -4.4454     9.9615 ]
// --- TFHandler_Factory        : var0*var2:     10.832     7.5632   [ 0.00088366     48.220 ]
// --- TFHandler_Factory        : var1+var2:     5.0910     1.7735   [    0.14162     9.8702 ]
// --- TFHandler_Factory        : ----------------------------------------------------------------
// --- TFHandler_Factory        : Plot event variables for Id
// --- TFHandler_Factory        : Create scatter and profile plots in target-file directory:
// --- TFHandler_Factory        : mydataset_output.root:/default/InputVariables_Id/CorrelationPlots
// --- TFHandler_Factory        :
// --- TFHandler_Factory        : Ranking input variables (method unspecific)...
// --- IdTransformation         : Ranking result (top variable is best ranked)
// --- IdTransformation         : -------------------------
// --- IdTransformation         : Rank : Variable  : Separation
// --- IdTransformation         : -------------------------
// --- IdTransformation         :    1 :  : 2.738e-01
// --- IdTransformation         :    2 :  : 5.815e-02
// --- IdTransformation         :    3 :  : 5.589e-02
// --- IdTransformation         : -------------------------
// --- Factory                  : Train method: BDT for Classification
// --- BDT                      : Dataset[default] : Begin training
// --- BDT                      :  found and suggest the following possible pre-selection cuts
// --- BDT                      : as option DoPreselection was not used, these cuts however will not be performed, but the training will see the full sample
// --- BDT                      :  found cut: Bkg if var 0 < -1.09749
// --- BDT                      : <InitEventSample> For classification trees,
// --- BDT                      :  the effective number of backgrounds is scaled to match
// --- BDT                      :  the signal. Othersise the first boosting step would do 'just that'!
// --- BDT                      : re-normlise events such that Sig and Bkg have respective sum of weights = 1
// --- BDT                      :   sig->sig*1ev. bkg->bkg*1ev.
// --- BDT                      : #events: (reweighted) sig: 3000 bkg: 3000
// --- BDT                      : #events: (unweighted) sig: 3000 bkg: 3000
// --- BDT                      : Training 200 Decision Trees ... patience please
// --- BinaryTree               : The minimal node size MinNodeSize=2.5 fMinNodeSize=2.5% is translated to an actual number of events = 76.175 for the training sample size of 3047
// --- BinaryTree               : Note: This number will be taken as absolute minimum in the node,
// --- BinaryTree               :       in terms of 'weighted events' and unweighted ones !!
// --- BDT                      : <Train> elapsed time: 0.561 sec
// --- BDT                      : <Train> average number of nodes (w/o pruning) : 4
// --- BDT                      : Dataset[default] : End of training
// --- BDT                      : Dataset[default] : Elapsed time for training with 6000 events: 0.575 sec
// --- BDT                      : Dataset[default] : Create MVA output for Dataset[default] : classification on training sample
// --- BDT                      : Dataset[default] : Evaluation of BDT on training sample (6000 events)
// --- BDT                      : Dataset[default] : Elapsed time for evaluation of 6000 events: 0.175 sec
// --- BDT                      : Dataset[default] : Creating weight file in xml format: transformed_dataset/weights/TMVAClassification_BDT.weights.xml
// --- BDT                      : Dataset[default] : Creating standalone response class: transformed_dataset/weights/TMVAClassification_BDT.class.C
// --- BDT                      : mydataset_output.root:/default/Method_BDT/BDT
// --- Factory                  : Training finished
// --- Factory                  : Train method: MLP for Classification
// --- MLP_Norm_TF              : Preparing the transformation.
// --- TFHandler_MLP            : ----------------------------------------------------------------
// --- TFHandler_MLP            : Variable  Mean RMS   [        Min       Max ]
// --- TFHandler_MLP            : ----------------------------------------------------------------
// --- TFHandler_MLP            : var0-var1:   -0.17548    0.30911   [    -1.0000     1.0000 ]
// --- TFHandler_MLP            : var0*var2:   -0.55077    0.31370   [    -1.0000     1.0000 ]
// --- TFHandler_MLP            : var1+var2:   0.017481    0.36460   [    -1.0000     1.0000 ]
// --- TFHandler_MLP            : ----------------------------------------------------------------
// --- MLP                      : Dataset[default] : Begin training
// --- MLP                      : Training Network
// --- MLP                      : Dataset[default] : End of training
// --- MLP                      : Dataset[default] : Elapsed time for training with 6000 events: 3.38 sec
// --- MLP                      : Dataset[default] : Create MVA output for Dataset[default] : classification on training sample
// --- MLP                      : Dataset[default] : Evaluation of MLP on training sample (6000 events)
// --- MLP                      : Dataset[default] : Elapsed time for evaluation of 6000 events: 0.00937 sec
// --- MLP                      : Dataset[default] : Creating weight file in xml format: transformed_dataset/weights/TMVAClassification_MLP.weights.xml
// --- MLP                      : Dataset[default] : Creating standalone response class: transformed_dataset/weights/TMVAClassification_MLP.class.C
// --- MLP                      : Write special histos to file: mydataset_output.root:/default/Method_MLP/MLP
// --- Factory                  : Training finished
// --- Factory                  : Train method: Fisher for Classification
// --- Fisher                   :
// --- Fisher                   : ================================================================
// --- Fisher                   : H e l p   f o r   M V A   m e t h o d   [ Fisher ] :
// --- Fisher                   :
// --- Fisher                   : --- Short description:
// --- Fisher                   :
// --- Fisher                   : Fisher discriminants select events by distinguishing the mean
// --- Fisher                   : values of the signal and background distributions in a trans-
// --- Fisher                   : formed variable space where linear correlations are removed.
// --- Fisher                   :
// --- Fisher                   :    (More precisely: the "linear discriminator" determines
// --- Fisher                   :     an axis in the (correlated) hyperspace of the input
// --- Fisher                   :     variables such that, when projecting the output classes
// --- Fisher                   :     (signal and background) upon this axis, they are pushed
// --- Fisher                   :     as far as possible away from each other, while events
// --- Fisher                   :     of a same class are confined in a close vicinity. The
// --- Fisher                   :     linearity property of this classifier is reflected in the
// --- Fisher                   :     metric with which "far apart" and "close vicinity" are
// --- Fisher                   :     determined: the covariance matrix of the discriminating
// --- Fisher                   :     variable space.)
// --- Fisher                   :
// --- Fisher                   : --- Performance optimisation:
// --- Fisher                   :
// --- Fisher                   : Optimal performance for Fisher discriminants is obtained for
// --- Fisher                   : linearly correlated Gaussian-distributed variables. Any deviation
// --- Fisher                   : from this ideal reduces the achievable separation power. In
// --- Fisher                   : particular, no discrimination at all is achieved for a variable
// --- Fisher                   : that has the same sample mean for signal and background, even if
// --- Fisher                   : the shapes of the distributions are very different. Thus, Fisher
// --- Fisher                   : discriminants often benefit from suitable transformations of the
// --- Fisher                   : input variables. For example, if a variable x in [-1,1] has a
// --- Fisher                   : a parabolic signal distributions, and a uniform background
// --- Fisher                   : distributions, their mean value is zero in both cases, leading
// --- Fisher                   : to no separation. The simple transformation x -> |x| renders this
// --- Fisher                   : variable powerful for the use in a Fisher discriminant.
// --- Fisher                   :
// --- Fisher                   : --- Performance tuning via configuration options:
// --- Fisher                   :
// --- Fisher                   : <None>
// --- Fisher                   :
// --- Fisher                   : <Suppress this message by specifying "!H" in the booking option>
// --- Fisher                   : ================================================================
// --- Fisher                   :
// --- Fisher                   : Dataset[default] : Begin training
// --- Fisher                   : Results for Fisher coefficients:
// --- Fisher                   : ------------------------
// --- Fisher                   : Variable:Coefficient:
// --- Fisher                   : ------------------------
// --- Fisher                   : var0-var1:+0.180
// --- Fisher                   : var0*var2:-0.031
// --- Fisher                   : var1+var2:+0.137
// --- Fisher                   : (offset):-0.631
// --- Fisher                   : ------------------------
// --- Fisher                   : Dataset[default] : End of training
// --- Fisher                   : Dataset[default] : Elapsed time for training with 6000 events: 0.00202 sec
// --- Fisher                   : Dataset[default] : Create MVA output for Dataset[default] : classification on training sample
// --- Fisher                   : Dataset[default] : Evaluation of Fisher on training sample (6000 events)
// --- Fisher                   : Dataset[default] : Elapsed time for evaluation of 6000 events: 0.000636 sec
// --- Fisher_PDFSig            : Validation result for PDF "Fisher_tr_S":
// --- Fisher_PDFSig            :     chi2/ndof(!=0) = 206.0/42 = 4.90 (Prob = 0.00)
// --- <WARNING> Fisher_PDFSig            : Comparison of the original histogram "Fisher_tr_S"
// --- <WARNING> Fisher_PDFSig            : with the corresponding PDF gave a chi2/ndof of 4.90442,
// --- <WARNING> Fisher_PDFSig            : which corresponds to a deviation of more than 5 sigma! Please check!
// --- Fisher_PDFSig            :     #bins-found(#expected-bins) deviating > [1,2,3,6] sigmas: [18(13),9(1),6(0),2(0)]
// --- Fisher_PDFBkg            : Validation result for PDF "Fisher_tr_B":
// --- Fisher_PDFBkg            :     chi2/ndof(!=0) = 35.8/37 = 0.97 (Prob = 0.53)
// --- Fisher_PDFBkg            :     #bins-found(#expected-bins) deviating > [1,2,3,6] sigmas: [13(11),2(1),0(0),0(0)]
// --- <WARNING> Fisher                   : Dataset[default] : Dataset[default] : could not calculate the separation, distributions fSplS or fSplB are not yet filled
// --- Fisher                   : <CreateMVAPdfs> Separation from histogram (PDF): 0.127 (0.000)
// --- Fisher                   : Dataset[default] : Evaluation of Fisher on training sample
// --- Fisher                   : Dataset[default] : Elapsed time for evaluation of 6000 events: 0.00218 sec
// --- Fisher                   : Dataset[default] : Creating weight file in xml format: transformed_dataset/weights/TMVAClassification_Fisher.weights.xml
// --- Fisher                   : Dataset[default] : Creating standalone response class: transformed_dataset/weights/TMVAClassification_Fisher.class.C
// --- Factory                  : Training finished
// --- Factory                  : Train method: Cuts for Classification
// --- Cuts                     : Dataset[default] : Begin training
// --- FitterBase               : <MCFitter> Sampling, please be patient ...
// --- FitterBase               : Elapsed time: 4.7 sec
// --- Cuts                     : ---------------------------------------------
// --- Cuts                     : Cut values for requested signal efficiency: 0.1
// --- Cuts                     : Corresponding background efficiency       : 0.001
// --- Cuts                     : Transformation applied to input variables : None
// --- Cuts                     : ---------------------------------------------
// --- Cuts                     : Cut[0]: 5.91004 < var0-var1 <= 1e+30
// --- Cuts                     : Cut[1]: 11.8979 < var0*var2 <= 1e+30
// --- Cuts                     : Cut[2]: -1e+30 < var1+var2 <= 9.87456
// --- Cuts                     : ---------------------------------------------
// --- Cuts                     : ---------------------------------------------
// --- Cuts                     : Cut values for requested signal efficiency: 0.2
// --- Cuts                     : Corresponding background efficiency       : 0.0463333
// --- Cuts                     : Transformation applied to input variables : None
// --- Cuts                     : ---------------------------------------------
// --- Cuts                     : Cut[0]: 3.05511 < var0-var1 <= 1e+30
// --- Cuts                     : Cut[1]: 13.9399 < var0*var2 <= 1e+30
// --- Cuts                     : Cut[2]: -1e+30 < var1+var2 <= 5.17774
// --- Cuts                     : ---------------------------------------------
// --- Cuts                     : ---------------------------------------------
// --- Cuts                     : Cut values for requested signal efficiency: 0.3
// --- Cuts                     : Corresponding background efficiency       : 0.158333
// --- Cuts                     : Transformation applied to input variables : None
// --- Cuts                     : ---------------------------------------------
// --- Cuts                     : Cut[0]: -3.7283 < var0-var1 <= 1e+30
// --- Cuts                     : Cut[1]: 9.35368 < var0*var2 <= 1e+30
// --- Cuts                     : Cut[2]: -1e+30 < var1+var2 <= 5.29144
// --- Cuts                     : ---------------------------------------------
// --- Cuts                     : ---------------------------------------------
// --- Cuts                     : Cut values for requested signal efficiency: 0.4
// --- Cuts                     : Corresponding background efficiency       : 0.264
// --- Cuts                     : Transformation applied to input variables : None
// --- Cuts                     : ---------------------------------------------
// --- Cuts                     : Cut[0]: -0.0415202 < var0-var1 <= 1e+30
// --- Cuts                     : Cut[1]: 11.7873 < var0*var2 <= 1e+30
// --- Cuts                     : Cut[2]: -1e+30 < var1+var2 <= 9.59129
// --- Cuts                     : ---------------------------------------------
// --- Cuts                     : ---------------------------------------------
// --- Cuts                     : Cut values for requested signal efficiency: 0.5
// --- Cuts                     : Corresponding background efficiency       : 0.347667
// --- Cuts                     : Transformation applied to input variables : None
// --- Cuts                     : ---------------------------------------------
// --- Cuts                     : Cut[0]: -0.0716729 < var0-var1 <= 1e+30
// --- Cuts                     : Cut[1]: 4.53843 < var0*var2 <= 1e+30
// --- Cuts                     : Cut[2]: -1e+30 < var1+var2 <= 5.3373
// --- Cuts                     : ---------------------------------------------
// --- Cuts                     : ---------------------------------------------
// --- Cuts                     : Cut values for requested signal efficiency: 0.6
// --- Cuts                     : Corresponding background efficiency       : 0.425667
// --- Cuts                     : Transformation applied to input variables : None
// --- Cuts                     : ---------------------------------------------
// --- Cuts                     : Cut[0]: -0.0385931 < var0-var1 <= 1e+30
// --- Cuts                     : Cut[1]: 7.95582 < var0*var2 <= 1e+30
// --- Cuts                     : Cut[2]: -1e+30 < var1+var2 <= 9.73314
// --- Cuts                     : ---------------------------------------------
// --- Cuts                     : ---------------------------------------------
// --- Cuts                     : Cut values for requested signal efficiency: 0.7
// --- Cuts                     : Corresponding background efficiency       : 0.505333
// --- Cuts                     : Transformation applied to input variables : None
// --- Cuts                     : ---------------------------------------------
// --- Cuts                     : Cut[0]: 0.00484862 < var0-var1 <= 1e+30
// --- Cuts                     : Cut[1]: 6.08015 < var0*var2 <= 1e+30
// --- Cuts                     : Cut[2]: -1e+30 < var1+var2 <= 9.86109
// --- Cuts                     : ---------------------------------------------
// --- Cuts                     : ---------------------------------------------
// --- Cuts                     : Cut values for requested signal efficiency: 0.8
// --- Cuts                     : Corresponding background efficiency       : 0.567667
// --- Cuts                     : Transformation applied to input variables : None
// --- Cuts                     : ---------------------------------------------
// --- Cuts                     : Cut[0]: -0.0545706 < var0-var1 <= 1e+30
// --- Cuts                     : Cut[1]: 4.60325 < var0*var2 <= 1e+30
// --- Cuts                     : Cut[2]: -1e+30 < var1+var2 <= 9.53412
// --- Cuts                     : ---------------------------------------------
// --- Cuts                     : ---------------------------------------------
// --- Cuts                     : Cut values for requested signal efficiency: 0.9
// --- Cuts                     : Corresponding background efficiency       : 0.639333
// --- Cuts                     : Transformation applied to input variables : None
// --- Cuts                     : ---------------------------------------------
// --- Cuts                     : Cut[0]: -0.0327968 < var0-var1 <= 1e+30
// --- Cuts                     : Cut[1]: 2.43337 < var0*var2 <= 1e+30
// --- Cuts                     : Cut[2]: -1e+30 < var1+var2 <= 9.76554
// --- Cuts                     : ---------------------------------------------
// --- Cuts                     : Dataset[default] : End of training
// --- Cuts                     : Dataset[default] : Elapsed time for training with 6000 events: 4.71 sec
// --- Cuts                     : Dataset[default] : Create MVA output for Dataset[default] : classification on training sample
// --- Cuts                     : Dataset[default] : Evaluation of Cuts on training sample (6000 events)
// --- Cuts                     : Dataset[default] : Elapsed time for evaluation of 6000 events: 0.000178 sec
// --- Cuts                     : Dataset[default] : Creating weight file in xml format: transformed_dataset/weights/TMVAClassification_Cuts.weights.xml
// --- Cuts                     : Dataset[default] : Creating standalone response class: transformed_dataset/weights/TMVAClassification_Cuts.class.C
// --- Cuts                     : mydataset_output.root:/default/Method_Cuts/Cuts
// --- Factory                  : Training finished
// --- Factory                  : Train method: SVM for Classification
// --- SVM                      : Dataset[default] : Begin training
// --- SVM                      : Building SVM Working Set...with 6000 event instances
// --- SVM                      : Elapsed time for Working Set build: 0.747 sec
// --- SVM                      : Sorry, no computing time forecast available for SVM, please wait ...
// --- SVM                      : Elapsed time: 29.8 sec
// --- SVM                      : Dataset[default] : End of training
// --- SVM                      : Dataset[default] : Elapsed time for training with 6000 events: 30.6 sec
// --- SVM                      : Dataset[default] : Create MVA output for Dataset[default] : classification on training sample
// --- SVM                      : Dataset[default] : Evaluation of SVM on training sample (6000 events)
// --- SVM                      : Dataset[default] : Elapsed time for evaluation of 6000 events: 1.03 sec
// --- SVM                      : Dataset[default] : Creating weight file in xml format: transformed_dataset/weights/TMVAClassification_SVM.weights.xml
// --- SVM                      : Dataset[default] : Creating standalone response class: transformed_dataset/weights/TMVAClassification_SVM.class.C
// --- Factory                  : Training finished
// --- Factory                  :
// --- Factory                  : Ranking input variables (method specific)...
// --- BDT                      : Ranking result (top variable is best ranked)
// --- BDT                      : -------------------------------------------
// --- BDT                      : Rank : Variable  : Variable Importance
// --- BDT                      : -------------------------------------------
// --- BDT                      :    1 : var0-var1 : 5.153e-01
// --- BDT                      :    2 : var1+var2 : 2.950e-01
// --- BDT                      :    3 : var0*var2 : 1.897e-01
// --- BDT                      : -------------------------------------------
// --- MLP                      : Ranking result (top variable is best ranked)
// --- MLP                      : ------------------------------------
// --- MLP                      : Rank : Variable  : Importance
// --- MLP                      : ------------------------------------
// --- MLP                      :    1 : var0_M_var1 : 2.713e+01
// --- MLP                      :    2 : var0_T_var2 : 1.505e+01
// --- MLP                      :    3 : var1_P_var2 : 6.728e+00
// --- MLP                      : ------------------------------------
// --- Fisher                   : Ranking result (top variable is best ranked)
// --- Fisher                   : ------------------------------------
// --- Fisher                   : Rank : Variable  : Discr. power
// --- Fisher                   : ------------------------------------
// --- Fisher                   :    1 : var0-var1 : 2.809e-02
// --- Fisher                   :    2 : var0*var2 : 2.010e-02
// --- Fisher                   :    3 : var1+var2 : 2.802e-04
// --- Fisher                   : ------------------------------------
// --- Factory                  : No variable ranking supplied by classifier: Cuts
// --- Factory                  : No variable ranking supplied by classifier: SVM
// --- Factory                  :
// --- Factory                  : === Destroy and recreate all methods via weight files for testing ===
// --- Factory                  :
// --- MethodBase               : Dataset[default] : Reading weight file: transformed_dataset/weights/TMVAClassification_BDT.weights.xml
// --- BDT                      : Dataset[default] : Read method "BDT" of type "BDT"
// --- BDT                      : Dataset[default] : MVA method was trained with TMVA Version: 4.2.1
// --- BDT                      : Dataset[default] : MVA method was trained with ROOT Version: 6.07/07
// --- MethodBase               : Dataset[default] : Reading weight file: transformed_dataset/weights/TMVAClassification_MLP.weights.xml
// --- MLP                      : Dataset[default] : Read method "MLP" of type "MLP"
// --- MLP                      : Dataset[default] : MVA method was trained with TMVA Version: 4.2.1
// --- MLP                      : Dataset[default] : MVA method was trained with ROOT Version: 6.07/07
// --- MLP                      : Building Network
// --- MLP                      : Initializing weights
// --- MethodBase               : Dataset[default] : Reading weight file: transformed_dataset/weights/TMVAClassification_Fisher.weights.xml
// --- Fisher                   : Dataset[default] : Read method "Fisher" of type "Fisher"
// --- Fisher                   : Dataset[default] : MVA method was trained with TMVA Version: 4.2.1
// --- Fisher                   : Dataset[default] : MVA method was trained with ROOT Version: 6.07/07
// --- MethodBase               : Dataset[default] : Reading weight file: transformed_dataset/weights/TMVAClassification_Cuts.weights.xml
// --- Cuts                     : Dataset[default] : Read method "Cuts" of type "Cuts"
// --- Cuts                     : Dataset[default] : MVA method was trained with TMVA Version: 4.2.1
// --- Cuts                     : Dataset[default] : MVA method was trained with ROOT Version: 6.07/07
// --- Cuts                     : Read cuts optimised using sample of MC events
// --- Cuts                     : Reading 100 signal efficiency bins for 3 variables
// --- MethodBase               : Dataset[default] : Reading weight file: transformed_dataset/weights/TMVAClassification_SVM.weights.xml
// --- SVM                      : Dataset[default] : Read method "SVM" of type "SVM"
// --- SVM                      : Dataset[default] : MVA method was trained with TMVA Version: 4.2.1
// --- SVM                      : Dataset[default] : MVA method was trained with ROOT Version: 6.07/07

// %%
factory->TestAllMethods();
factory->EvaluateAllMethods();
// Out:
// --- Factory                  : Test all methods...
// --- Factory                  : Test method: BDT for Classification performance
// --- BDT                      : Dataset[mydataset] : Evaluation of BDT on testing sample (2898 events)
// --- BDT                      : Dataset[mydataset] : Elapsed time for evaluation of 2898 events: 0.0584 sec
// --- Factory                  : Test method: MLP for Classification performance
// --- MLP                      : Dataset[mydataset] : Evaluation of MLP on testing sample (2898 events)
// --- MLP                      : Dataset[mydataset] : Elapsed time for evaluation of 2898 events: 0.00749 sec
// --- Factory                  : Test method: Fisher for Classification performance
// --- Fisher                   : Dataset[mydataset] : Evaluation of Fisher on testing sample (2898 events)
// --- Fisher                   : Dataset[mydataset] : Elapsed time for evaluation of 2898 events: 0.000514 sec
// --- Fisher                   : Dataset[mydataset] : Evaluation of Fisher on testing sample
// --- Fisher                   : Dataset[mydataset] : Elapsed time for evaluation of 2898 events: 0.000726 sec
// --- Factory                  : Test method: Cuts for Classification performance
// --- Cuts                     : Dataset[mydataset] : Evaluation of Cuts on testing sample (2898 events)
// --- Cuts                     : Dataset[mydataset] : Elapsed time for evaluation of 2898 events: 9.61e-05 sec
// --- Factory                  : Test method: SVM for Classification performance
// --- SVM                      : Dataset[mydataset] : Evaluation of SVM on testing sample (2898 events)
// --- SVM                      : Dataset[mydataset] : Elapsed time for evaluation of 2898 events: 0.318 sec
// --- Factory                  : Test method: BDT for Classification performance
// --- BDT                      : Dataset[default] : Evaluation of BDT on testing sample (2898 events)
// --- BDT                      : Dataset[default] : Elapsed time for evaluation of 2898 events: 0.0742 sec
// --- Factory                  : Test method: MLP for Classification performance
// --- MLP                      : Dataset[default] : Evaluation of MLP on testing sample (2898 events)
// --- MLP                      : Dataset[default] : Elapsed time for evaluation of 2898 events: 0.00899 sec
// --- Factory                  : Test method: Fisher for Classification performance
// --- Fisher                   : Dataset[default] : Evaluation of Fisher on testing sample (2898 events)
// --- Fisher                   : Dataset[default] : Elapsed time for evaluation of 2898 events: 0.000338 sec
// --- Fisher                   : Dataset[default] : Evaluation of Fisher on testing sample
// --- Fisher                   : Dataset[default] : Elapsed time for evaluation of 2898 events: 0.000778 sec
// --- Factory                  : Test method: Cuts for Classification performance
// --- Cuts                     : Dataset[default] : Evaluation of Cuts on testing sample (2898 events)
// --- Cuts                     : Dataset[default] : Elapsed time for evaluation of 2898 events: 9.7e-05 sec
// --- Factory                  : Test method: SVM for Classification performance
// --- SVM                      : Dataset[default] : Evaluation of SVM on testing sample (2898 events)
// --- SVM                      : Dataset[default] : Elapsed time for evaluation of 2898 events: 0.388 sec
// --- Factory                  : Evaluate all methods...
// --- Factory                  : Evaluate classifier: BDT
// --- BDT                      : Dataset[mydataset] : Loop over test events and fill histograms with classifier response...
// --- Factory                  : Write evaluation histograms to file
// --- TFHandler_BDT            : Plot event variables for BDT
// --- TFHandler_BDT            : -----------------------------------------------------------
// --- TFHandler_BDT            : Variable  Mean RMS   [        Min       Max ]
// --- TFHandler_BDT            : -----------------------------------------------------------
// --- TFHandler_BDT            : var0:     3.0193     1.6845   [   0.043718     9.9537 ]
// --- TFHandler_BDT            : var1:     1.6150     1.4437   [ 0.00012225     4.9956 ]
// --- TFHandler_BDT            : var2:     3.4963     1.2016   [ 0.00072440     5.0000 ]
// --- TFHandler_BDT            : var3:     1.4044     2.1855   [    -4.0521     9.9031 ]
// --- TFHandler_BDT            : var4:     10.577     7.4095   [ 0.00097392     48.593 ]
// --- TFHandler_BDT            : var5:     5.1112     1.8209   [    0.17973     9.9030 ]
// --- TFHandler_BDT            : -----------------------------------------------------------
// --- TFHandler_BDT            : Create scatter and profile plots in target-file directory:
// --- TFHandler_BDT            : mydataset_output.root:/mydataset/Method_BDT/BDT/CorrelationPlots
// --- Factory                  : Evaluate classifier: MLP
// --- TFHandler_MLP            : -----------------------------------------------------------
// --- TFHandler_MLP            : Variable  Mean RMS   [        Min       Max ]
// --- TFHandler_MLP            : -----------------------------------------------------------
// --- TFHandler_MLP            : var0:   -0.40192    0.33854   [   -0.99993    0.99170 ]
// --- TFHandler_MLP            : var1:   -0.35362    0.57785   [   -0.99999    0.99955 ]
// --- TFHandler_MLP            : var2:    0.39861    0.48081   [    -1.0001     1.0003 ]
// --- TFHandler_MLP            : var3:   -0.18793    0.30339   [   -0.94541    0.99189 ]
// --- TFHandler_MLP            : var4:   -0.56133    0.30733   [    -1.0000     1.0155 ]
// --- TFHandler_MLP            : var5:   0.021649    0.37434   [   -0.99217     1.0067 ]
// --- TFHandler_MLP            : -----------------------------------------------------------
// --- MLP                      : Dataset[mydataset] : Loop over test events and fill histograms with classifier response...
// --- Factory                  : Write evaluation histograms to file
// --- TFHandler_MLP            : Plot event variables for MLP
// --- TFHandler_MLP            : -----------------------------------------------------------
// --- TFHandler_MLP            : Variable  Mean RMS   [        Min       Max ]
// --- TFHandler_MLP            : -----------------------------------------------------------
// --- TFHandler_MLP            : var0:   -0.40192    0.33854   [   -0.99993    0.99170 ]
// --- TFHandler_MLP            : var1:   -0.35362    0.57785   [   -0.99999    0.99955 ]
// --- TFHandler_MLP            : var2:    0.39861    0.48081   [    -1.0001     1.0003 ]
// --- TFHandler_MLP            : var3:   -0.18793    0.30339   [   -0.94541    0.99189 ]
// --- TFHandler_MLP            : var4:   -0.56133    0.30733   [    -1.0000     1.0155 ]
// --- TFHandler_MLP            : var5:   0.021649    0.37434   [   -0.99217     1.0067 ]
// --- TFHandler_MLP            : -----------------------------------------------------------
// --- TFHandler_MLP            : Create scatter and profile plots in target-file directory:
// --- TFHandler_MLP            : mydataset_output.root:/mydataset/Method_MLP/MLP/CorrelationPlots
// --- Factory                  : Evaluate classifier: Fisher
// --- Fisher                   : Dataset[mydataset] : Loop over test events and fill histograms with classifier response...
// --- Fisher                   : Also filling probability and rarity histograms (on request)...
// --- Factory                  : Write evaluation histograms to file
// --- TFHandler_Fisher         : Plot event variables for Fisher
// --- TFHandler_Fisher         : -----------------------------------------------------------
// --- TFHandler_Fisher         : Variable  Mean RMS   [        Min       Max ]
// --- TFHandler_Fisher         : -----------------------------------------------------------
// --- TFHandler_Fisher         : var0:     3.0193     1.6845   [   0.043718     9.9537 ]
// --- TFHandler_Fisher         : var1:     1.6150     1.4437   [ 0.00012225     4.9956 ]
// --- TFHandler_Fisher         : var2:     3.4963     1.2016   [ 0.00072440     5.0000 ]
// --- TFHandler_Fisher         : var3:     1.4044     2.1855   [    -4.0521     9.9031 ]
// --- TFHandler_Fisher         : var4:     10.577     7.4095   [ 0.00097392     48.593 ]
// --- TFHandler_Fisher         : var5:     5.1112     1.8209   [    0.17973     9.9030 ]
// --- TFHandler_Fisher         : -----------------------------------------------------------
// --- TFHandler_Fisher         : Create scatter and profile plots in target-file directory:
// --- TFHandler_Fisher         : mydataset_output.root:/mydataset/Method_Fisher/Fisher/CorrelationPlots
// --- Factory                  : Evaluate classifier: Cuts
// --- <WARNING> ResultsCuts              : You have asked for histogram MVA_EFF_BvsS which does not seem to exist in *Results* .. better don't use it
// --- <WARNING> ResultsCuts              : You have asked for histogram EFF_BVSS_TR which does not seem to exist in *Results* .. better don't use it
// --- <WARNING> Cuts                     :  unable to fill 6 efficiency bins
// --- Factory                  : Write evaluation histograms to file
// --- TFHandler_Cuts           : Plot event variables for Cuts
// --- TFHandler_Cuts           : -----------------------------------------------------------
// --- TFHandler_Cuts           : Variable  Mean RMS   [        Min       Max ]
// --- TFHandler_Cuts           : -----------------------------------------------------------
// --- TFHandler_Cuts           : var0:     3.0193     1.6845   [   0.043718     9.9537 ]
// --- TFHandler_Cuts           : var1:     1.6150     1.4437   [ 0.00012225     4.9956 ]
// --- TFHandler_Cuts           : var2:     3.4963     1.2016   [ 0.00072440     5.0000 ]
// --- TFHandler_Cuts           : var3:     1.4044     2.1855   [    -4.0521     9.9031 ]
// --- TFHandler_Cuts           : var4:     10.577     7.4095   [ 0.00097392     48.593 ]
// --- TFHandler_Cuts           : var5:     5.1112     1.8209   [    0.17973     9.9030 ]
// --- TFHandler_Cuts           : -----------------------------------------------------------
// --- TFHandler_Cuts           : Create scatter and profile plots in target-file directory:
// --- TFHandler_Cuts           : mydataset_output.root:/mydataset/Method_Cuts/Cuts/CorrelationPlots
// --- Factory                  : Evaluate classifier: SVM
// --- SVM                      : Dataset[mydataset] : Loop over test events and fill histograms with classifier response...
// --- Factory                  : Write evaluation histograms to file
// --- TFHandler_SVM            : Plot event variables for SVM
// --- TFHandler_SVM            : -----------------------------------------------------------
// --- TFHandler_SVM            : Variable  Mean RMS   [        Min       Max ]
// --- TFHandler_SVM            : -----------------------------------------------------------
// --- TFHandler_SVM            : var0:     3.0193     1.6845   [   0.043718     9.9537 ]
// --- TFHandler_SVM            : var1:     1.6150     1.4437   [ 0.00012225     4.9956 ]
// --- TFHandler_SVM            : var2:     3.4963     1.2016   [ 0.00072440     5.0000 ]
// --- TFHandler_SVM            : var3:     1.4044     2.1855   [    -4.0521     9.9031 ]
// --- TFHandler_SVM            : var4:     10.577     7.4095   [ 0.00097392     48.593 ]
// --- TFHandler_SVM            : var5:     5.1112     1.8209   [    0.17973     9.9030 ]
// --- TFHandler_SVM            : -----------------------------------------------------------
// --- TFHandler_SVM            : Create scatter and profile plots in target-file directory:
// --- TFHandler_SVM            : mydataset_output.root:/mydataset/Method_SVM/SVM/CorrelationPlots
// --- Factory                  :
// --- Factory                  : Evaluation results ranked by best signal efficiency and purity (area)
// --- Factory                  : -------------------------------------------------------------------------------------------------------------------
// --- Factory                  : DataSet              MVA              Signal efficiency at bkg eff.(error):                | Sepa-    Signifi-
// --- Factory                  : Name:                Method:          @B=0.01    @B=0.10    @B=0.30    ROC-integ    ROCCurve| ration:  cance:
// --- Factory                  : -------------------------------------------------------------------------------------------------------------------
// --- Factory                  : mydataset            MLP            : 0.167(09)  0.598(12)  0.888(08)    0.878       0.878 | 0.447    1.244
// --- Factory                  : mydataset            BDT            : 0.170(09)  0.568(13)  0.892(08)    0.875       0.875 | 0.436    1.182
// --- Factory                  : mydataset            SVM            : 0.043(05)  0.538(13)  0.871(08)    0.852       0.851 | 0.400    1.129
// --- Factory                  : mydataset            Fisher         : 0.051(05)  0.328(12)  0.650(12)    0.736       0.735 | 0.170    0.631
// --- Factory                  : mydataset            Cuts           : 0.123(08)  0.296(11)  0.582(12)    0.678       0.000 | --       --
// --- Factory                  : -------------------------------------------------------------------------------------------------------------------
// --- Factory                  :
// --- Factory                  : Testing efficiency compared to training efficiency (overtraining check)
// --- Factory                  : -------------------------------------------------------------------------------------------------------------------
// --- Factory                  : DataSet              MVA              Signal efficiency: from test sample (from training sample)
// --- Factory                  : Name:                Method:          @B=0.01             @B=0.10            @B=0.30
// --- Factory                  : -------------------------------------------------------------------------------------------------------------------
// --- Factory                  : mydataset            MLP            : 0.167 (0.238)       0.598 (0.621)      0.888 (0.894)
// --- Factory                  : mydataset            BDT            : 0.170 (0.225)       0.568 (0.604)      0.892 (0.893)
// --- Factory                  : mydataset            SVM            : 0.043 (0.065)       0.538 (0.604)      0.871 (0.881)
// --- Factory                  : mydataset            Fisher         : 0.051 (0.056)       0.328 (0.327)      0.650 (0.646)
// --- Factory                  : mydataset            Cuts           : 0.123 (0.158)       0.296 (0.341)      0.582 (0.616)
// --- Factory                  : -------------------------------------------------------------------------------------------------------------------
// --- Factory                  :
// --- Dataset:mydataset        : Dataset[mydataset] : Created tree 'TestTree' with 2898 events
// --- Dataset:mydataset        : Dataset[mydataset] : Created tree 'TrainTree' with 6000 events
// --- Factory                  : Evaluate classifier: BDT
// --- BDT                      : Dataset[default] : Loop over test events and fill histograms with classifier response...
// --- Factory                  : Write evaluation histograms to file
// --- TFHandler_BDT            : Plot event variables for BDT
// --- TFHandler_BDT            : ----------------------------------------------------------------
// --- TFHandler_BDT            : Variable  Mean RMS   [        Min       Max ]
// --- TFHandler_BDT            : ----------------------------------------------------------------
// --- TFHandler_BDT            : var0-var1:     1.4044     2.1855   [    -4.0521     9.9031 ]
// --- TFHandler_BDT            : var0*var2:     10.577     7.4095   [ 0.00097392     48.593 ]
// --- TFHandler_BDT            : var1+var2:     5.1112     1.8209   [    0.17973     9.9030 ]
// --- TFHandler_BDT            : ----------------------------------------------------------------
// --- TFHandler_BDT            : Create scatter and profile plots in target-file directory:
// --- TFHandler_BDT            : mydataset_output.root:/default/Method_BDT/BDT/CorrelationPlots
// --- Factory                  : Evaluate classifier: MLP
// --- TFHandler_MLP            : ----------------------------------------------------------------
// --- TFHandler_MLP            : Variable  Mean RMS   [        Min       Max ]
// --- TFHandler_MLP            : ----------------------------------------------------------------
// --- TFHandler_MLP            : var0-var1:   -0.18793    0.30339   [   -0.94541    0.99189 ]
// --- TFHandler_MLP            : var0*var2:   -0.56133    0.30733   [    -1.0000     1.0155 ]
// --- TFHandler_MLP            : var1+var2:   0.021649    0.37434   [   -0.99217     1.0067 ]
// --- TFHandler_MLP            : ----------------------------------------------------------------
// --- MLP                      : Dataset[default] : Loop over test events and fill histograms with classifier response...
// --- Factory                  : Write evaluation histograms to file
// --- TFHandler_MLP            : Plot event variables for MLP
// --- TFHandler_MLP            : ----------------------------------------------------------------
// --- TFHandler_MLP            : Variable  Mean RMS   [        Min       Max ]
// --- TFHandler_MLP            : ----------------------------------------------------------------
// --- TFHandler_MLP            : var0-var1:   -0.18793    0.30339   [   -0.94541    0.99189 ]
// --- TFHandler_MLP            : var0*var2:   -0.56133    0.30733   [    -1.0000     1.0155 ]
// --- TFHandler_MLP            : var1+var2:   0.021649    0.37434   [   -0.99217     1.0067 ]
// --- TFHandler_MLP            : ----------------------------------------------------------------
// --- TFHandler_MLP            : Create scatter and profile plots in target-file directory:
// --- TFHandler_MLP            : mydataset_output.root:/default/Method_MLP/MLP/CorrelationPlots
// --- Factory                  : Evaluate classifier: Fisher
// --- Fisher                   : Dataset[default] : Loop over test events and fill histograms with classifier response...
// --- Fisher                   : Also filling probability and rarity histograms (on request)...
// --- Factory                  : Write evaluation histograms to file
// --- TFHandler_Fisher         : Plot event variables for Fisher
// --- TFHandler_Fisher         : ----------------------------------------------------------------
// --- TFHandler_Fisher         : Variable  Mean RMS   [        Min       Max ]
// --- TFHandler_Fisher         : ----------------------------------------------------------------
// --- TFHandler_Fisher         : var0-var1:     1.4044     2.1855   [    -4.0521     9.9031 ]
// --- TFHandler_Fisher         : var0*var2:     10.577     7.4095   [ 0.00097392     48.593 ]
// --- TFHandler_Fisher         : var1+var2:     5.1112     1.8209   [    0.17973     9.9030 ]
// --- TFHandler_Fisher         : ----------------------------------------------------------------
// --- TFHandler_Fisher         : Create scatter and profile plots in target-file directory:
// --- TFHandler_Fisher         : mydataset_output.root:/default/Method_Fisher/Fisher/CorrelationPlots
// --- Factory                  : Evaluate classifier: Cuts
// --- <WARNING> ResultsCuts              : You have asked for histogram MVA_EFF_BvsS which does not seem to exist in *Results* .. better don't use it
// --- <WARNING> ResultsCuts              : You have asked for histogram EFF_BVSS_TR which does not seem to exist in *Results* .. better don't use it
// --- Factory                  : Write evaluation histograms to file
// --- TFHandler_Cuts           : Plot event variables for Cuts
// --- TFHandler_Cuts           : ----------------------------------------------------------------
// --- TFHandler_Cuts           : Variable  Mean RMS   [        Min       Max ]
// --- TFHandler_Cuts           : ----------------------------------------------------------------
// --- TFHandler_Cuts           : var0-var1:     1.4044     2.1855   [    -4.0521     9.9031 ]
// --- TFHandler_Cuts           : var0*var2:     10.577     7.4095   [ 0.00097392     48.593 ]
// --- TFHandler_Cuts           : var1+var2:     5.1112     1.8209   [    0.17973     9.9030 ]
// --- TFHandler_Cuts           : ----------------------------------------------------------------
// --- TFHandler_Cuts           : Create scatter and profile plots in target-file directory:
// --- TFHandler_Cuts           : mydataset_output.root:/default/Method_Cuts/Cuts/CorrelationPlots
// --- Factory                  : Evaluate classifier: SVM
// --- SVM                      : Dataset[default] : Loop over test events and fill histograms with classifier response...
// --- Factory                  : Write evaluation histograms to file
// --- TFHandler_SVM            : Plot event variables for SVM
// --- TFHandler_SVM            : ----------------------------------------------------------------
// --- TFHandler_SVM            : Variable  Mean RMS   [        Min       Max ]
// --- TFHandler_SVM            : ----------------------------------------------------------------
// --- TFHandler_SVM            : var0-var1:     1.4044     2.1855   [    -4.0521     9.9031 ]
// --- TFHandler_SVM            : var0*var2:     10.577     7.4095   [ 0.00097392     48.593 ]
// --- TFHandler_SVM            : var1+var2:     5.1112     1.8209   [    0.17973     9.9030 ]
// --- TFHandler_SVM            : ----------------------------------------------------------------
// --- TFHandler_SVM            : Create scatter and profile plots in target-file directory:
// --- TFHandler_SVM            : mydataset_output.root:/default/Method_SVM/SVM/CorrelationPlots
// --- Factory                  :
// --- Factory                  : Evaluation results ranked by best signal efficiency and purity (area)
// --- Factory                  : -------------------------------------------------------------------------------------------------------------------
// --- Factory                  : DataSet              MVA              Signal efficiency at bkg eff.(error):                | Sepa-    Signifi-
// --- Factory                  : Name:                Method:          @B=0.01    @B=0.10    @B=0.30    ROC-integ    ROCCurve| ration:  cance:
// --- Factory                  : -------------------------------------------------------------------------------------------------------------------
// --- Factory                  : transformed_dataset  MLP            : 0.142(09)  0.492(13)  0.782(10)    0.826       0.826 | 0.336    0.973
// --- Factory                  : transformed_dataset  SVM            : 0.052(05)  0.455(13)  0.773(11)    0.811       0.812 | 0.303    0.902
// --- Factory                  : transformed_dataset  BDT            : 0.129(08)  0.466(13)  0.741(11)    0.809       0.810 | 0.301    0.885
// --- Factory                  : transformed_dataset  Cuts           : 0.115(08)  0.215(10)  0.383(12)    0.638       0.000 | --       --
// --- Factory                  : transformed_dataset  Fisher         : 0.079(07)  0.187(10)  0.354(12)    0.607       0.608 | 0.103    0.333
// --- Factory                  : -------------------------------------------------------------------------------------------------------------------
// --- Factory                  :
// --- Factory                  : Testing efficiency compared to training efficiency (overtraining check)
// --- Factory                  : -------------------------------------------------------------------------------------------------------------------
// --- Factory                  : DataSet              MVA              Signal efficiency: from test sample (from training sample)
// --- Factory                  : Name:                Method:          @B=0.01             @B=0.10            @B=0.30
// --- Factory                  : -------------------------------------------------------------------------------------------------------------------
// --- Factory                  : default              MLP            : 0.142 (0.191)       0.492 (0.544)      0.782 (0.801)
// --- Factory                  : default              SVM            : 0.052 (0.059)       0.455 (0.534)      0.773 (0.797)
// --- Factory                  : default              BDT            : 0.129 (0.172)       0.466 (0.502)      0.741 (0.779)
// --- Factory                  : default              Cuts           : 0.115 (0.154)       0.215 (0.256)      0.383 (0.456)
// --- Factory                  : default              Fisher         : 0.079 (0.095)       0.187 (0.184)      0.354 (0.353)
// --- Factory                  : -------------------------------------------------------------------------------------------------------------------
// --- Factory                  :
// --- Dataset:default          : Dataset[default] : Created tree 'TestTree' with 2898 events
// --- Dataset:default          : Dataset[default] : Created tree 'TrainTree' with 6000 events
// --- Factory                  :
// --- Factory                  : Thank you for using TMVA!
// --- Factory                  : For citation information, please visit: http://tmva.sf.net/citeTMVA.html

// %%
%jsroot on
auto c1 = factory->VarTransformROCPlot(loader1, loader2);
c1->Draw();
// Out:
// [<unknown binary>]
// [<unknown binary>]
//  *** Break *** segmentation violation
// [/Users/testuser/root-build/lib/libTMVA.so] TMVA::Factory::VarTransformROCPlot(TMVA::DataLoader*, TMVA::DataLoader*) /Users/testuser/root/tmva/tmva/src/Factory.cxx:2224
// [<unknown binary>]

// %%
auto c2 = factory->GetROCCurve(loader2);
c2->Draw();
